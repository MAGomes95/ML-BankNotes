# %% [markdown]
# ### Imports

# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### Get the Data

# %%
data = pd.read_csv("TP1-data.csv", header=None)
data.columns=["variance", "skewness" ,"curtosis of Wavelet Transformed image", "entropy of the bank note image", "class label"]

# %%
data.head()
# Out:
#    variance  skewness  curtosis of Wavelet Transformed image  \
# 0   3.62160    8.6661                                -2.8073
# 1   4.54590    8.1674                                -2.4586
# 2   3.86600   -2.6383                                 1.9242
# 3   3.45660    9.5228                                -4.0112
# 4   0.32924   -4.4552                                 4.5718
#
#    entropy of the bank note image  class label
# 0                        -0.44699            0
# 1                        -1.46210            0
# 2                         0.10645            0
# 3                        -3.59440            0
# 4                        -0.98880            0

# %%
data.isnull().sum()
# Out:
# variance                                 0
# skewness                                 0
# curtosis of Wavelet Transformed image    0
# entropy of the bank note image           0
# class label                              0
# dtype: int64

# %%
data.shape
# Out:
# (1372, 5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1372 entries, 0 to 1371
# Data columns (total 5 columns):
# variance                                 1372 non-null float64
# skewness                                 1372 non-null float64
# curtosis of Wavelet Transformed image    1372 non-null float64
# entropy of the bank note image           1372 non-null float64
# class label                              1372 non-null int64
# dtypes: float64(4), int64(1)
# memory usage: 53.7 KB

# %%
data.describe()
# Out:
#           variance     skewness  curtosis of Wavelet Transformed image  \
# count  1372.000000  1372.000000                            1372.000000
# mean      0.433735     1.922353                               1.397627
# std       2.842763     5.869047                               4.310030
# min      -7.042100   -13.773100                              -5.286100
# 25%      -1.773000    -1.708200                              -1.574975
# 50%       0.496180     2.319650                               0.616630
# 75%       2.821475     6.814625                               3.179250
# max       6.824800    12.951600                              17.927400
#
#        entropy of the bank note image  class label
# count                     1372.000000  1372.000000
# mean                        -1.191657     0.444606
# std                          2.101013     0.497103
# min                         -8.548200     0.000000
# 25%                         -2.413450     0.000000
# ...

# %%
data["class label"].value_counts()
# Out:
# 0    762
# 1    610
# Name: class label, dtype: int64

# %%
#Distribuiçao de outputs
ax = data["class label"].value_counts(dropna=False).plot(kind='bar', title='True outputs distribuition',color='green');
ax.grid(False)

# %%
sns.heatmap(data.corr(),annot=True);

# %%
sns.pairplot(data, hue="class label")
# Out:
# C:\Users\Miguel-PC\Anaconda3\envs\ldsa\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# C:\Users\Miguel-PC\Anaconda3\envs\ldsa\lib\site-packages\statsmodels\nonparametric\kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\Users\Miguel-PC\Anaconda3\envs\ldsa\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# C:\Users\Miguel-PC\Anaconda3\envs\ldsa\lib\site-packages\numpy\core\fromnumeric.py:83: RuntimeWarning: invalid value encountered in reduce
# ...

# %%
# !jupyter nbconvert --to script Data_Analysis.ipynb
# Out:
# [NbConvertApp] Converting notebook Data_Analysis.ipynb to script
# [NbConvertApp] Writing 937 bytes to Data_Analysis.py
